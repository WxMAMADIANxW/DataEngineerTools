# %% [markdown]
# # Introduction

# %% [markdown]
# Aujourd'hui la plupart des sites web utilisent du JavaScript pour rendre le site plus dynamique et agréable mais aussi pour afficher la données.
#
# Pour ces sites, la première méthode abordée n'est pas efficace, car de nombreuses requêtes sont utilisées pour se connecter, afficher la donnée, naviguer, il faudrait prendre en compte toutes ces requêtes et les assembler pour simuler le comportement du site.
#
# **C'est le comportement de votre navigateur**, il compile toutes les interactions, les requêtes et génère du HTML permettant d'afficher l'interface graphique d'un site web.
#
# Pour palier ce problème on peut laisser le navigateur faire son travail et contrôler sa surcouche logiciel. Pour cela on peut prendre le contrôle d'un navigateur comme Chrome, Edge, Firefox ou Safari depuis un script Python.
#
# Pour cela, nous allons utiliser un package Python `Selenium` https://selenium-python.readthedocs.io/ qui permet d'instancier un navigateur et de le contrôler. Sélénium est beaucoup utilisé pour générer des tests automatiques de sites web.
#
# On peut trouver les drivers des différents browser :
# - Chrome:	https://sites.google.com/a/chromium.org/chromedriver/downloads
# - Edge:	https://developer.microsoft.com/en-us/microsoft-edge/tools/webdriver/
# - Firefox:	https://github.com/mozilla/geckodriver/releases
# - Safari:	https://webkit.org/blog/6900/webdriver-support-in-safari-10/

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\mamadian\appdata\local\continuum\anaconda3\lib\site-packages (3.141.0)
# Requirement already satisfied: urllib3 in c:\users\mamadian\appdata\local\continuum\anaconda3\lib\site-packages (from selenium) (1.24.1)

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

# %%
# !pip install webdriver-manager
# Out:
# Requirement already satisfied: webdriver-manager in c:\users\mamadian\appdata\local\continuum\anaconda3\lib\site-packages (3.3.0)
# Requirement already satisfied: requests in c:\users\mamadian\appdata\local\continuum\anaconda3\lib\site-packages (from webdriver-manager) (2.21.0)
# Requirement already satisfied: crayons in c:\users\mamadian\appdata\local\continuum\anaconda3\lib\site-packages (from webdriver-manager) (0.4.0)
# Requirement already satisfied: configparser in c:\users\mamadian\appdata\local\continuum\anaconda3\lib\site-packages (from webdriver-manager) (5.0.2)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\mamadian\appdata\local\continuum\anaconda3\lib\site-packages (from requests->webdriver-manager) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\mamadian\appdata\local\continuum\anaconda3\lib\site-packages (from requests->webdriver-manager) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\mamadian\appdata\local\continuum\anaconda3\lib\site-packages (from requests->webdriver-manager) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mamadian\appdata\local\continuum\anaconda3\lib\site-packages (from requests->webdriver-manager) (2019.3.9)
# Requirement already satisfied: colorama in c:\users\mamadian\appdata\local\continuum\anaconda3\lib\site-packages (from crayons->webdriver-manager) (0.4.1)

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
url = "https://www.amazon.fr"
driver.get(url)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 89.0.4389
# [WDM] - Get LATEST driver version for 89.0.4389
# [WDM] - Driver [C:\Users\Mamadian\.wdm\drivers\chromedriver\win32\89.0.4389.23\chromedriver.exe] found in cache

# %% [markdown]
# Allez maintenant voir votre fenêtre. Vous êtes sur le site d'amazon. Vous pouvez maintenant vous déplacer dans la page. Pour cela il va falloir inspecter le code source de la page.
#
# Il existe de nombreuse méthode pour récupérer les éléments par exemple `find_element_by_link_text` qui permet de récupérer un élément grâce au text affiché. Ici, si on veut récupérer toutes les `Ventes Flash`

# %%
link = driver.find_element_by_link_text("Voir tout")
type(link)
# Out:
# selenium.webdriver.remote.webelement.WebElement

# %% [markdown]
# Si on veut entrer dans le lien, il suffit d'appeler la méthode `click`.

# %%
link.click()

# %% [markdown]
# Vous êtes arrivé sur la page des ventes flash. Maintenant nous allons récupérer toutes les ventes actuelles. On remarque que les ventes sont stockés dans des widgets qui porte l'id `widgetContent`.

# %%
all_widgets = driver.find_elements_by_id("widgetContent")
type(all_widgets), len(all_widgets)
# Out:
# (list, 1)

# %% [markdown]
# On obtient une liste d'éléments décrits par cet identifiant. Il y en a 5, un pour chaque ligne. Pour récupérer les différentes offres de la première ligne. on récupère les sections correspondantes:

# %%
first_line = all_widgets[0]
all_first_line_elements = first_line.find_elements_by_class_name('a-section')
len(all_first_line_elements)
# Out:
# 120

# %% [markdown]
# Pour récupérer le text maintenant :

# %%
_ = [print(elt.text+ "\n")  for elt in all_first_line_elements]
# Out:
# 29,99 €
# Prix conseillé : 59,99 € (-50%)
# Echo Dot (4e génération)
# 7882
# Voir l'offre
#
# 29,99 €
# Prix conseillé : 59,99 € (-50%)
# Echo Dot (4e génération)
# 7882
# Voir l'offre
#
#
#
# 29,99 €
# Prix conseillé : 59,99 € (-50%)
# Echo Dot (4e génération)
# 7882
# Voir l'offre
#
# 89,99 € - 129,99 €
# Kindle Paperwhite
# 10020
# Voir l'offre
#
# 89,99 € - 129,99 €
# Kindle Paperwhite
# 10020
# Voir l'offre
#
#
#
# 89,99 € - 129,99 €
# Kindle Paperwhite
# 10020
# Voir l'offre
#
# OFFRE STAR
# 3,93 € - 52,49 €
# Termine dans 7 jours
# Jusqu'à -25% sur les produits du quotidien des marques exclusives ...
# Voir l'offre
#
# OFFRE STAR
# 3,93 € - 52,49 €
# Termine dans 7 jours
# Jusqu'à -25% sur les produits du quotidien des marques exclusives ...
# Voir l'offre
#
#
#
# OFFRE STAR
# 3,93 € - 52,49 €
# Termine dans 7 jours
# Jusqu'à -25% sur les produits du quotidien des marques exclusives ...
# Voir l'offre
#
# AmazonBasics et plus encore
# Voir l'offre
#
# AmazonBasics et plus encore
# Voir l'offre
#
#
#
# AmazonBasics et plus encore
# Voir l'offre
#
# OFFRE STAR
# 7,00 € - 39,74 €
# Termine dans 7 jours
# Pampers : Jusqu'à -40% sur une sélection de couches et couches-c...
# 45069
# Voir l'offre
#
# OFFRE STAR
# 7,00 € - 39,74 €
# Termine dans 7 jours
# Pampers : Jusqu'à -40% sur une sélection de couches et couches-c...
# 45069
# Voir l'offre
#
#
#
# OFFRE STAR
# 7,00 € - 39,74 €
# Termine dans 7 jours
# Pampers : Jusqu'à -40% sur une sélection de couches et couches-c...
# 45069
# Voir l'offre
#
# OFFRE STAR
# 82,99 € - 164,99 €
# Termine dans 4 jours
# Crucial: Jusqu'à -30% sur une sélection de produits
# 5310
# Voir l'offre
#
# OFFRE STAR
# 82,99 € - 164,99 €
# Termine dans 4 jours
# Crucial: Jusqu'à -30% sur une sélection de produits
# 5310
# Voir l'offre
#
#
#
# OFFRE STAR
# 82,99 € - 164,99 €
# Termine dans 4 jours
# Crucial: Jusqu'à -30% sur une sélection de produits
# 5310
# Voir l'offre
#
# OFFRE STAR
# 9,99 € - 349,99 €
# Termine dans 7 jours
# Singer, Brother : jusqu'à -33% sur une sélection de produits couture
# 969
# Voir l'offre
#
# OFFRE STAR
# 9,99 € - 349,99 €
# Termine dans 7 jours
# Singer, Brother : jusqu'à -33% sur une sélection de produits couture
# 969
# Voir l'offre
#
#
#
# OFFRE STAR
# 9,99 € - 349,99 €
# Termine dans 7 jours
# Singer, Brother : jusqu'à -33% sur une sélection de produits couture
# 969
# Voir l'offre
#
# OFFRE STAR
# 8,00 € - 79,90 €
# Termine dans 7 jours
# Eastpak, Vans, Kipling et Pepe Jeans: Sac à dos et accessoires
# 30502
# Voir l'offre
#
# OFFRE STAR
# 8,00 € - 79,90 €
# Termine dans 7 jours
# Eastpak, Vans, Kipling et Pepe Jeans: Sac à dos et accessoires
# 30502
# Voir l'offre
#
#
#
# OFFRE STAR
# 8,00 € - 79,90 €
# Termine dans 7 jours
# Eastpak, Vans, Kipling et Pepe Jeans: Sac à dos et accessoires
# 30502
# Voir l'offre
#
# OFFRE STAR
# 11,99 € - 164,99 €
# Termine dans 7 jours
# Lagostina, Tefal: jusqu'à -50% sur une sélection cuisine
# 2921
# Voir l'offre
#
# OFFRE STAR
# 11,99 € - 164,99 €
# Termine dans 7 jours
# Lagostina, Tefal: jusqu'à -50% sur une sélection cuisine
# 2921
# Voir l'offre
#
#
#
# OFFRE STAR
# 11,99 € - 164,99 €
# Termine dans 7 jours
# Lagostina, Tefal: jusqu'à -50% sur une sélection cuisine
# 2921
# Voir l'offre
#
# OFFRE STAR
# 9,99 € - 430,99 €
# Termine dans 14:57:27
# Bosch : jusqu'à -25% sur une sélection de produits
# 3962
# Voir l'offre
#
# OFFRE STAR
# 9,99 € - 430,99 €
# Termine dans 14:57:27
# Bosch : jusqu'à -25% sur une sélection de produits
# 3962
# Voir l'offre
#
#
#
# OFFRE STAR
# 9,99 € - 430,99 €
# Termine dans 14:57:27
# Bosch : jusqu'à -25% sur une sélection de produits
# 3962
# Voir l'offre
#
# OFFRE STAR
# 149,90 € - 649,00 €
# Termine dans 7 jours
# Aspirateurs robot : Jusqu'à -43% sur Irobot, Ecovas, Rowenta...
# 4867
# Voir l'offre
#
# OFFRE STAR
# 149,90 € - 649,00 €
# Termine dans 7 jours
# Aspirateurs robot : Jusqu'à -43% sur Irobot, Ecovas, Rowenta...
# 4867
# Voir l'offre
#
#
#
# OFFRE STAR
# 149,90 € - 649,00 €
# Termine dans 7 jours
# Aspirateurs robot : Jusqu'à -43% sur Irobot, Ecovas, Rowenta...
# 4867
# Voir l'offre
#
# OFFRE STAR
# 97,99 € - 333,99 €
# Termine dans 14:57:27
# Cybex sièges enfants
# 668
# Voir l'offre
#
# OFFRE STAR
# 97,99 € - 333,99 €
# Termine dans 14:57:27
# Cybex sièges enfants
# 668
# Voir l'offre
#
#
#
# OFFRE STAR
# 97,99 € - 333,99 €
# Termine dans 14:57:27
# Cybex sièges enfants
# 668
# Voir l'offre
#
# OFFRE STAR
# 89,99 € - 179,99 €
# Termine dans 7 jours
# Jusqu'à -50% sur une sélection d'aspirateurs
# 864
# Voir l'offre
#
# OFFRE STAR
# 89,99 € - 179,99 €
# Termine dans 7 jours
# Jusqu'à -50% sur une sélection d'aspirateurs
# 864
# Voir l'offre
#
#
#
# OFFRE STAR
# 89,99 € - 179,99 €
# Termine dans 7 jours
# Jusqu'à -50% sur une sélection d'aspirateurs
# 864
# Voir l'offre
#
# OFFRE STAR
# 67,99 € - 249,99 €
# Termine dans 7 jours
# Aspirateurs traineau : Jusqu'à -27% sur Rowenta, Bosch, Hoover, …
# 120
# Voir l'offre
#
# OFFRE STAR
# 67,99 € - 249,99 €
# Termine dans 7 jours
# Aspirateurs traineau : Jusqu'à -27% sur Rowenta, Bosch, Hoover, …
# 120
# Voir l'offre
#
#
#
# OFFRE STAR
# 67,99 € - 249,99 €
# Termine dans 7 jours
# Aspirateurs traineau : Jusqu'à -27% sur Rowenta, Bosch, Hoover, …
# 120
# Voir l'offre
#
# OFFRE STAR
# 9,90 € - 119,90 €
# Termine dans 7 jours
# TP-Link : jusqu'à -40% sur une sélection de produits. -5% supplé...
# 8285
# Voir l'offre
#
# OFFRE STAR
# 9,90 € - 119,90 €
# Termine dans 7 jours
# TP-Link : jusqu'à -40% sur une sélection de produits. -5% supplé...
# 8285
# Voir l'offre
#
#
#
# OFFRE STAR
# 9,90 € - 119,90 €
# Termine dans 7 jours
# TP-Link : jusqu'à -40% sur une sélection de produits. -5% supplé...
# 8285
# Voir l'offre
#
# OFFRE STAR
# 26,32 € - 77,77 €
# Termine dans 7 jours
# Offre sur une sélection de chaussures Clarks
# 4
# Voir l'offre
#
# OFFRE STAR
# 26,32 € - 77,77 €
# Termine dans 7 jours
# Offre sur une sélection de chaussures Clarks
# 4
# Voir l'offre
#
#
#
# OFFRE STAR
# 26,32 € - 77,77 €
# Termine dans 7 jours
# Offre sur une sélection de chaussures Clarks
# 4
# Voir l'offre
#
# OFFRE STAR
# 9,45 € - 53,94 €
# Termine dans 7 jours
# Huggies, DryNites, PullUps: jusqu'à -30% sur une sélection de produit...
# 941
# Voir l'offre
#
# OFFRE STAR
# 9,45 € - 53,94 €
# Termine dans 7 jours
# Huggies, DryNites, PullUps: jusqu'à -30% sur une sélection de produit...
# 941
# Voir l'offre
#
#
#
# OFFRE STAR
# 9,45 € - 53,94 €
# Termine dans 7 jours
# Huggies, DryNites, PullUps: jusqu'à -30% sur une sélection de produit...
# 941
# Voir l'offre
#
# OFFRE STAR
# 195,99 € - 1.339,00 €
# Termine dans 6 jours
# Best of Robots: jusqu'à -40% sur une sélection de produits
# 439
# Voir l'offre
#
# OFFRE STAR
# 195,99 € - 1.339,00 €
# Termine dans 6 jours
# Best of Robots: jusqu'à -40% sur une sélection de produits
# 439
# Voir l'offre
#
#
#
# OFFRE STAR
# 195,99 € - 1.339,00 €
# Termine dans 6 jours
# Best of Robots: jusqu'à -40% sur une sélection de produits
# 439
# Voir l'offre
#
# OFFRE STAR
# 2,50 € - 3,73 €
# Termine dans 5 jours
# Sélection de masques jetables
# 2504
# Voir l'offre
#
# OFFRE STAR
# 2,50 € - 3,73 €
# Termine dans 5 jours
# Sélection de masques jetables
# 2504
# Voir l'offre
#
#
#
# OFFRE STAR
# 2,50 € - 3,73 €
# Termine dans 5 jours
# Sélection de masques jetables
# 2504
# Voir l'offre
#
# OFFRE STAR
# 10,99 € - 63,29 €
# Termine dans 7 jours
# BLACK SHIELD - Lots de masques médicaux chirurgicaux noirs
# 22
# Voir l'offre
#
# OFFRE STAR
# 10,99 € - 63,29 €
# Termine dans 7 jours
# BLACK SHIELD - Lots de masques médicaux chirurgicaux noirs
# 22
# Voir l'offre
#
#
#
# OFFRE STAR
# 10,99 € - 63,29 €
# Termine dans 7 jours
# BLACK SHIELD - Lots de masques médicaux chirurgicaux noirs
# 22
# Voir l'offre
#
# OFFRE STAR
# 5,52 € - 32,15 €
# Termine dans 7 jours
# Skip, Ariel, Vanish : jusqu'à -35% sur une sélection de lessives
# 1197
# Voir l'offre
#
# OFFRE STAR
# 5,52 € - 32,15 €
# Termine dans 7 jours
# Skip, Ariel, Vanish : jusqu'à -35% sur une sélection de lessives
# 1197
# Voir l'offre
#
#
#
# OFFRE STAR
# 5,52 € - 32,15 €
# Termine dans 7 jours
# Skip, Ariel, Vanish : jusqu'à -35% sur une sélection de lessives
# 1197
# Voir l'offre
#
# OFFRE STAR
# 64,99 € - 399,99 €
# Termine dans 7 jours
# Aspirateurs balai : Jusqu'à -38% sur Rowenta, Philips, Bosch, ... -5% su...
# 380
# Voir l'offre
#
# OFFRE STAR
# 64,99 € - 399,99 €
# Termine dans 7 jours
# Aspirateurs balai : Jusqu'à -38% sur Rowenta, Philips, Bosch, ... -5% su...
# 380
# Voir l'offre
#
#
#
# OFFRE STAR
# 64,99 € - 399,99 €
# Termine dans 7 jours
# Aspirateurs balai : Jusqu'à -38% sur Rowenta, Philips, Bosch, ... -5% su...
# 380
# Voir l'offre
#
# OFFRE STAR
# 10,99 € - 99,99 €
# Termine dans 7 jours
# Sélection de Blu-Ray et DVDs
# 13
# Voir l'offre
#
# OFFRE STAR
# 10,99 € - 99,99 €
# Termine dans 7 jours
# Sélection de Blu-Ray et DVDs
# 13
# Voir l'offre
#
#
#
# OFFRE STAR
# 10,99 € - 99,99 €
# Termine dans 7 jours
# Sélection de Blu-Ray et DVDs
# 13
# Voir l'offre
#
# OFFRE STAR
# 22,99 € - 51,99 €
# Termine dans 7 jours
# Brita : jusqu'à -34% sur une sélection carafes filtrantes. -5% ...
# 10703
# Voir l'offre
#
# OFFRE STAR
# 22,99 € - 51,99 €
# Termine dans 7 jours
# Brita : jusqu'à -34% sur une sélection carafes filtrantes. -5% ...
# 10703
# Voir l'offre
# OFFRE STAR
# 22,99 € - 51,99 €
# Termine dans 7 jours
# Brita : jusqu'à -34% sur une sélection carafes filtrantes. -5% ...
# 10703
# Voir l'offre
#
# OFFRE STAR
# 9,09 € - 21,47 €
# Termine dans 7 jours
# Finish : jusqu'à -49% sur les produits du lave-vaiselle. -5% sup...
# 5051
# Voir l'offre
#
# OFFRE STAR
# 9,09 € - 21,47 €
# Termine dans 7 jours
# Finish : jusqu'à -49% sur les produits du lave-vaiselle. -5% sup...
# 5051
# Voir l'offre
#
#
#
# OFFRE STAR
# 9,09 € - 21,47 €
# Termine dans 7 jours
# Finish : jusqu'à -49% sur les produits du lave-vaiselle. -5% sup...
# 5051
# Voir l'offre
#
# OFFRE STAR
# 39,90 €
# Prix : 49,90 € (-20%)
# Termine dans 14:57:24
# Sélection de jeux et jouets
# Vendu et expédié par Aosom fr
# 7
# Ajouter au panier
#
# OFFRE STAR
# 39,90 €
# Prix : 49,90 € (-20%)
# Termine dans 14:57:24
# Sélection de jeux et jouets
# Vendu et expédié par Aosom fr
# 7
# Ajouter au panier
#
#
#
# OFFRE STAR
# 39,90 €
# Prix : 49,90 € (-20%)
# Termine dans 14:57:24
# Sélection de jeux et jouets
# Vendu et expédié par Aosom fr
# 7
# Ajouter au panier
#
# OFFRE STAR
# 36,99 € - 213,99 €
# Termine dans 14:57:24
# Dremel : jusqu'à -25% sur une sélection de produits
# 4082
# Voir l'offre
#
# OFFRE STAR
# 36,99 € - 213,99 €
# Termine dans 14:57:24
# Dremel : jusqu'à -25% sur une sélection de produits
# 4082
# Voir l'offre
#
#
#
# OFFRE STAR
# 36,99 € - 213,99 €
# Termine dans 14:57:24
# Dremel : jusqu'à -25% sur une sélection de produits
# 4082
# Voir l'offre
#
# OFFRE STAR
# 5,00 € - 37,69 €
# Termine dans 7 jours
# Swiffer, Vileda, Airwick : Jusqu'à -40% sur une sélection de produit...
# 440
# Voir l'offre
#
# OFFRE STAR
# 5,00 € - 37,69 €
# Termine dans 7 jours
# Swiffer, Vileda, Airwick : Jusqu'à -40% sur une sélection de produit...
# 440
# Voir l'offre
#
#
#
# OFFRE STAR
# 5,00 € - 37,69 €
# Termine dans 7 jours
# Swiffer, Vileda, Airwick : Jusqu'à -40% sur une sélection de produit...
# 440
# Voir l'offre
#
# OFFRE STAR
# 5,59 € - 23,77 €
# Termine dans 7 jours
# Durex: jusqu'à -30% sur les préservatifs et gels
# 2657
# Voir l'offre
#
# OFFRE STAR
# 5,59 € - 23,77 €
# Termine dans 7 jours
# Durex: jusqu'à -30% sur les préservatifs et gels
# 2657
# Voir l'offre
#
#
#
# OFFRE STAR
# 5,59 € - 23,77 €
# Termine dans 7 jours
# Durex: jusqu'à -30% sur les préservatifs et gels
# 2657
# Voir l'offre
#
# OFFRE STAR
# 8,59 € - 10,99 €
# Termine dans 7 jours
# Duracell : Jusqu'à -55% sur les piles alcalines et rechargeables
# 47321
# Voir l'offre
#
# OFFRE STAR
# 8,59 € - 10,99 €
# Termine dans 7 jours
# Duracell : Jusqu'à -55% sur les piles alcalines et rechargeables
# 47321
# Voir l'offre
#
#
#
# OFFRE STAR
# 8,59 € - 10,99 €
# Termine dans 7 jours
# Duracell : Jusqu'à -55% sur les piles alcalines et rechargeables
# 47321
# Voir l'offre

# %% [markdown]
# Si vous êtes fan de JavaScript vous pouvez même injecter du code JS dans le navigateur depuis Python pour exécuter des opérations complexes.

# %%
js_script = """
const class_name = 'DRIOC'
console.log(`Hi from ${class_name}`)
"""

# %%
chrome.execute_script(js_script)

# %% [markdown]
# Vous pouvez aller vérifier dans la console Javascript du navigateur que le message apparait bien.

# %% [markdown]
# # Exercice

# %% [markdown]
# ## Exercice 1

# %% [markdown]
# Extraire le prix des offres :

# %%
from bs4 import BeautifulSoup

# %%
def extract_price(offer_web_element):
    try:
        
    except:
        
    raise NotImplementedError('Need to be implemented')
    pass

extract_price(all_first_line_elements[0])
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-58-e6d4c1fd13d9> in <module>
#       3     pass
#       4
# ----> 5 extract_price(all_first_line_elements[0])
#
# <ipython-input-58-e6d4c1fd13d9> in extract_price(offer_web_element)
#       1 def extract_price(offer_web_element):
# ----> 2     raise NotImplementedError('Need to be implemented')
#       3     pass
#       4
#       5 extract_price(all_first_line_elements[0])
#
# NotImplementedError: Need to be implemented

# %% [markdown]
# Extraire l'image de l'offre:

# %%
def extract_image(offer_web_element):
    raise NotImplementedError('Need to be implemented')
    pass

extract_image(all_first_line_elements[0])
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-78-63850a8c42cb> in <module>()
#       3     pass
#       4
# ----> 5 extract_image(all_first_line_elements[0])
#
# <ipython-input-78-63850a8c42cb> in extract_image(offer_web_element)
#       1 def extract_image(offer_web_element):
# ----> 2     raise NotImplementedError('Need to be implemented')
#       3     pass
#       4
#       5 extract_image(all_first_line_elements[0])
#
# NotImplementedError: Need to be implemented

# %% [markdown]
# Extraire le titre de l'offre:

# %%
def extract_title(offer_web_element):
    raise NotImplementedError('Need to be implemented')
    pass

extract_title(all_first_line_elements[0])
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-79-a4f7a74d5827> in <module>()
#       3     pass
#       4
# ----> 5 extract_title(all_first_line_elements[0])
#
# <ipython-input-79-a4f7a74d5827> in extract_title(offer_web_element)
#       1 def extract_title(offer_web_element):
# ----> 2     raise NotImplementedError('Need to be implemented')
#       3     pass
#       4
#       5 extract_title(all_first_line_elements[0])
#
# NotImplementedError: Need to be implemented

# %%
chrome.close()
